# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df1= pd.read_csv('files_for_lab/csv_files/file1.csv')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv('files_for_lab/csv_files/file2.csv')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3= pd.read_csv('files_for_lab/csv_files/file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1.columns = [df1.columns[i].upper().replace(' ', '_') for i in range(len(df1.columns))]
df1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER_LIFETIME_VALUE',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'POLICY_TYPE', 'VEHICLE_CLASS', 'TOTAL_CLAIM_AMOUNT'],
#       dtype='object')

# %%
df2.columns = [df2.columns[i].upper().replace(' ', '_') for i in range(len(df2.columns))]
df2.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER_LIFETIME_VALUE',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'TOTAL_CLAIM_AMOUNT', 'POLICY_TYPE', 'VEHICLE_CLASS'],
#       dtype='object')

# %%
df3.columns = [df3.columns[i].upper().replace(' ', '_') for i in range(len(df3.columns))]
df3.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER_LIFETIME_VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'POLICY_TYPE', 'TOTAL_CLAIM_AMOUNT', 'VEHICLE_CLASS'],
#       dtype='object')

# %%
df1.columns.values[1] = "STATE"
df1
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.columns.values[1] = "STATE"
df2
# Out:
#     CUSTOMER       STATE GENDER EDUCATION CUSTOMER_LIFETIME_VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY_PREMIUM_AUTO NUMBER_OF_OPEN_COMPLAINTS  TOTAL_CLAIM_AMOUNT  \
# ...

# %%
data_joined = pd.concat([df1, df2, df3])
data_joined
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data_joined['CUSTOMER_LIFETIME_VALUE'] = data_joined['CUSTOMER_LIFETIME_VALUE'].str.rstrip("%").astype(float)/100
data_joined
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
data_joined['NUMBER_OF_OPEN_COMPLAINTS'] = data_joined['NUMBER_OF_OPEN_COMPLAINTS'].str.replace("/", "").astype(float)
data_joined
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
data_joined.dtypes
# Out:
# CUSTOMER                      object
# STATE                         object
# GENDER                        object
# EDUCATION                     object
# CUSTOMER_LIFETIME_VALUE      float64
# INCOME                       float64
# MONTHLY_PREMIUM_AUTO         float64
# NUMBER_OF_OPEN_COMPLAINTS    float64
# POLICY_TYPE                   object
# VEHICLE_CLASS                 object
# TOTAL_CLAIM_AMOUNT           float64
# dtype: object

# %%
numericals = data_joined.select_dtypes("number")
numericals
# Out:
#       CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# 3                   7645.8618      0.0                 106.0
# 4                   5363.0765  36357.0                  68.0
# ...                       ...      ...                   ...
# 7065                      NaN  71941.0                  73.0
# 7066                      NaN  21604.0                  79.0
# 7067                      NaN      0.0                  85.0
# 7068                      NaN  21941.0                  96.0
# 7069                      NaN      0.0                  77.0
#
#       NUMBER_OF_OPEN_COMPLAINTS  TOTAL_CLAIM_AMOUNT
# 0                        1000.0            2.704934
# 1                        1000.0         1131.464935
# 2                        1000.0          566.472247
# ...

# %%
categoricals = data_joined.select_dtypes('object')
categoricals
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION     POLICY_TYPE  \
# 0     RB50392  Washington    NaN                Master   Personal Auto
# 1     QZ44356     Arizona      F              Bachelor   Personal Auto
# 2     AI49188      Nevada      F              Bachelor   Personal Auto
# 3     WW63253  California      M              Bachelor  Corporate Auto
# 4     GA49547  Washington      M  High School or Below   Personal Auto
# ...       ...         ...    ...                   ...             ...
# 7065  LA72316  California      M              Bachelor   Personal Auto
# 7066  PK87824  California      F               College  Corporate Auto
# 7067  TD14365  California      M              Bachelor  Corporate Auto
# 7068  UP19263  California      M               College   Personal Auto
# 7069  Y167826  California      M               College  Corporate Auto
#
#       VEHICLE_CLASS
# 0     Four-Door Car
# 1     Four-Door Car
# 2      Two-Door Car
# 3               SUV
# ...

# %%
data_joined.drop(columns=['EDUCATION', 'NUMBER_OF_OPEN_COMPLAINTS'])
# Out:
#      CUSTOMER       STATE GENDER  CUSTOMER_LIFETIME_VALUE   INCOME  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                6979.5359      0.0
# 2     AI49188      Nevada      F               12887.4317  48767.0
# 3     WW63253  California      M                7645.8618      0.0
# 4     GA49547  Washington      M                5363.0765  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       MONTHLY_PREMIUM_AUTO     POLICY_TYPE  VEHICLE_CLASS  TOTAL_CLAIM_AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data_joined.drop_duplicates()
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                         NaN      0.0                1000.0
# 1                   6979.5359      0.0                  94.0
# 2                  12887.4317  48767.0                 108.0
# ...

# %%
data_joined[data_joined['INCOME'] <= 0]
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103  California      F              Bachelor
# 7061  RX91025  California      M  High School or Below
# 7062  AC13887  California      M              Bachelor
# 7067  TD14365  California      M              Bachelor
# 7069  Y167826  California      M               College
#
#       CUSTOMER_LIFETIME_VALUE  INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                         NaN     0.0                1000.0
# 1                   6979.5359     0.0                  94.0
# 3                   7645.8618     0.0                 106.0
# ...
